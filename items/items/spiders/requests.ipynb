# %%
from pymongo import MongoClient
from dotenv import load_dotenv
import os

load_dotenv()

ATLAS_KEY=os.getenv('ATLAS_KEY')
print(ATLAS_KEY)
# Out:
# mongodb+srv://Rola:PULNnDzUngmgjKUf@cluster0.dab6uno.mongodb.net/test

# %%
client = MongoClient(ATLAS_KEY)

# %%
db = client.imdb
collection = db.movies
collection
# Out:
# Collection(Database(MongoClient(host=['ac-ps571lr-shard-00-01.dab6uno.mongodb.net:27017', 'ac-ps571lr-shard-00-02.dab6uno.mongodb.net:27017', 'ac-ps571lr-shard-00-00.dab6uno.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-jeswvs-shard-0', tls=True), 'imdb'), 'movies')

# %%
# # iterate over all documents in the collection
# for document in collection.find():
#     duration = document["duration"]
#     hours, minutes = map(int, duration.split("h "))
#     total_minutes = hours * 60 + minutes
#     # update the duration field for the current document
#     collection.update_one(
#         {"_id": document["_id"]},
#         {"$set": {"duration": total_minutes}}
#     )

# %%
for document in collection.find():
    duration = document["duration"]
    if duration != 'nan':
        if len(duration.split()) == 2  :
                x=int(duration.split()[0][0])*60 + int(duration.split()[1][0 : len(duration.split()[1])-1])
        elif duration.split()[0][-1] == 'h':
                x=int(duration.split('h')[0])*60
        elif duration.split()[0][-1] == 'm':
                x=int(duration.split('m')[0])
        print(x)
#     # x_max=max(x)
#     st.write(x)
#     # st.write(dict_duration)
# Out:
# 142
# 175
# 152
# 202
# 102
# 122
# 170
# 148
# 181
# 142
# 90
# 146
# 86
# 94
# 83
# 105
# 99
# 172
# 145
# 127
# 130
# 154
# 112
# 164
# 129
# 121
# 93
# 125
# 143
# 98
# 99
# 115
# 101
# 80
# 121
# 123
# 89
# 107
# 137
# 129
# 111
# 120
# 120
# 121
# 152
# 114
# 136
# 117
# 118
# 124
# 128
# 92
# 98
# 96
# 92
# 120
# 129
# 45
# 122
# 132
# 131
# 139
# 93
# 183
# 133
# 185
# 67
# 91
# 149
# 99
# 108
# 212
# 134
# 101
# 130
# 96
# 95
# 117
# 89
# 132
# 86
# 141
# 169
# 116
# 140
# 98
# 153
# 161
# 93
# 115
# 119
# 129
# 95
# 105
# 107
# 238
# 132
# 129
# 130
# 124
# 100
# 148
# 109
# 88
# 172
# 111
# 122
# 91
# 126
# 110
# 127
# 135
# 138
# 107
# 130
# 118
# 158
# 103
# 178
# 162
# 179
# 130
# 180
# 138
# 97
# 121
# 68
# 140
# 132
# 161
# 156
# 130
# 119
# 165
# 89
# 102
# 127
# 132
# 114
# 138
# 153
# 123
# 129
# 96
# 129
# 170
# 131
# 160
# 170
# 116
# 136
# 107
# 122
# 125
# 128
# 136
# 143
# 99
# 218
# 119
# 115
# 99
# 142
# 108
# 149
# 131
# 126
# 103
# 143
# 102
# 170
# 103
# 106
# 126
# 229
# 134
# 181
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 4
#       2 duration = document["duration"]
#       3 if duration != 'nan':
# ----> 4     if len(duration.split()) == 2  :
#       5             x=int(duration.split()[0][0])*60 + int(duration.split()[1][0 : len(duration.split()[1])-1])
#       6     elif duration.split()[0][-1] == 'h':
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
df['duration'][180]
# Out:
# '1h 21m'

# %%
# for document in collection.find():
# duration = "2h"

for document in collection.find():
    duration = document["duration"]
    if len(duration.split()) >= 2  :
        x=int(duration.split()[0][0])*60+ int(duration.split()[1][0 : len(duration.split()[1])-1])
    else:
        x=int(duration.split('h')[0][0])*60
    print(x)
# Out:
# 142
# 175
# 152
# 202
# 120
# 129
# 111
# 120
# 123
# 90
# 181
# 142
# 146
# 86
# 94
# 83
# 105
# 99
# 172
# 145
# 127
# 130
# 154
# 112
# 164
# 129
# 121
# 93
# 125
# 143
# 98
# 99
# 115
# 101
# 122
# 170
# 102
# 148
# 80
# 121
# 89
# 107
# 137
# 121
# 152
# 114
# 136
# 117
# 118
# 124
# 128
# 92
# 98
# 96
# 92
# 120
# 129
# 240
# 122
# 132
# 131
# 139
# 93
# 183
# 133
# 185
# 67
# 91
# 149
# 99
# 108
# 212
# 134
# 101
# 130
# 96
# 95
# 117
# 89
# 132
# 86
# 141
# 169
# 116
# 140
# 98
# 153
# 161
# 93
# 115
# 119
# 129
# 95
# 105
# 107
# 238
# 132
# 129
# 130
# 124
# 100
# 148
# 109
# 88
# 172
# 111
# 122

# %%
result = collection.find().sort("duree",-1).limit(1)
for movie in result:

# %%
import pandas as pd
# read the CSV file into a DataFrame
df = pd.read_csv("movies.csv")

# display the first few rows of the DataFrame
print(df.head())
df
# Out:
#                       title  score      genre  year duration  \
# 0  The Shawshank Redemption    9.3      Drama  1994   2h 22m
# 1             The Godfather    9.2      Crime  1972   2h 55m
# 2           The Dark Knight    9.0     Action  2008   2h 32m
# 3     The Godfather Part II    9.0      Crime  1974   3h 22m
# 4                 Spotlight    8.1  Biography  2015    2h 9m
#
#                                          description  \
# 0  Over the course of several years, two convicts...
# 1  The aging patriarch of an organized crime dyna...
# 2  When the menace known as the Joker wreaks havo...
# 3  The early life and career of Vito Corleone in ...
# 4  The true story of how the Boston Globe uncover...
#
#                                               actors public        country  \
# 0  Tim Robbins,Morgan Freeman,Bob Gunton,William ...      R  United States
# 1  Marlon Brando,Al Pacino,James Caan,Diane Keato...      R  United States
# 2  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...  PG-13  United States
# 3  Al Pacino,Robert De Niro,Robert Duvall,Diane K...      R  United States
# 4  Mark Ruffalo,Michael Keaton,Rachel McAdams,Lie...      R  United States
#
#   language
# 0  English
# 1      NaN
# 2  English
# 3      NaN
# 4      NaN
#                                                  title  score      genre  \
# 0                             The Shawshank Redemption    9.3      Drama
# 1                                        The Godfather    9.2      Crime
# 2                                      The Dark Knight    9.0     Action
# 3                                The Godfather Part II    9.0      Crime
# 4                                            Spotlight    8.1  Biography
# ..                                                 ...    ...        ...
# 245  The Lord of the Rings: The Fellowship of the Ring    8.8     Action
# 246                                       Pulp Fiction    8.9      Crime
# 247      The Lord of the Rings: The Return of the King    9.0     Action
# 248                                   Schindler's List    9.0  Biography
# 249                                       12 Angry Men    9.0      Crime
#
#      year duration                                        description  \
# 0    1994   2h 22m  Over the course of several years, two convicts...
# 1    1972   2h 55m  The aging patriarch of an organized crime dyna...
# 2    2008   2h 32m  When the menace known as the Joker wreaks havo...
# 3    1974   3h 22m  The early life and career of Vito Corleone in ...
# 4    2015    2h 9m  The true story of how the Boston Globe uncover...
# ..    ...      ...                                                ...
# 245  2001   2h 58m  A meek Hobbit from the Shire and eight compani...
# 246  1994   2h 34m  The lives of two mob hitmen, a boxer, a gangst...
# 247  2003   3h 21m  Gandalf and Aragorn lead the World of Men agai...
# 248  1993   3h 15m  In German-occupied Poland during World War II,...
# 249  1957   1h 36m  The jury in a New York City murder trial is fr...
#
#                                                 actors    public  \
# 0    Tim Robbins,Morgan Freeman,Bob Gunton,William ...         R
# 1    Marlon Brando,Al Pacino,James Caan,Diane Keato...         R
# 2    Christian Bale,Heath Ledger,Aaron Eckhart,Mich...     PG-13
# 3    Al Pacino,Robert De Niro,Robert Duvall,Diane K...         R
# 4    Mark Ruffalo,Michael Keaton,Rachel McAdams,Lie...         R
# ..                                                 ...       ...
# 245  Elijah Wood,Ian McKellen,Orlando Bloom,Sean Be...     PG-13
# 246  John Travolta,Uma Thurman,Samuel L. Jackson,Br...         R
# 247  Elijah Wood,Viggo Mortensen,Ian McKellen,Orlan...     PG-13
# 248  Liam Neeson,Ralph Fiennes,Ben Kingsley,Carolin...         R
# 249  Henry Fonda,Lee J. Cobb,Martin Balsam,John Fie...  Approved
#
#            country language
# 0    United States  English
# 1    United States      NaN
# 2    United States  English
# 3    United States      NaN
# 4    United States      NaN
# ..             ...      ...
# 245    New Zealand  English
# 246  United States  English
# 247    New Zealand  English
# 248  United States  English
# 249  United States      NaN
#
# [250 rows x 10 columns]

# %%
df['duration'][177
            ]
# Out:
# nan

# %%
dict_duration ={}
for document in collection.find():
    duration = document["duration"]
    title = document["title"]
    if len(duration.split()) == 2 and duration != 'nan': 
        x=int(duration.split()[0][0])*60 + int(duration.split()[1][0 : len(duration.split()[1])-1])
    elif duration.split()[0][-1] == 'h' and duration != 'nan': 
        x=int(duration.split('h')[0])*60
    elif duration.split()[0][-1] == 'm' and duration != 'nan': 
        x=int(duration.split('m')[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 5
#       3 duration = document["duration"]
#       4 title = document["title"]
# ----> 5 if len(duration.split()) == 2 and duration != 'nan':
#       6     x=int(duration.split()[0][0])*60 + int(duration.split()[1][0 : len(duration.split()[1])-1])
#       7 elif duration.split()[0][-1] == 'h' and duration != 'nan':
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
dict_duration ={}
for document in collection.find():
    duration = document["duration"]
    print(duration)
    title = document["title"]
    if len(duration.split()) == 2 and duration != None: 
        x=int(duration.split()[0][0])*60 + int(duration.split()[1][0 : len(duration.split()[1])-1])
    elif duration.split()[0][-1] == 'h' and duration != None: 
        x=int(duration.split('h')[0])*60
    elif duration.split()[0][-1] == 'm' and duration != None: 
        x=int(duration.split('m')[0])
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
dict_duration = {}
for document in collection.find():
    duration = document["duration"]
    title = document["title"]
    if duration is not None:
        if len(duration.split()) == 2:
            x = int(duration.split()[0][0]) * 60 + int(duration.split()[1][0 : len(duration.split()[1])-1])
        elif duration.split()[0][-1] == 'h':
            x = int(duration.split('h')[0]) * 60
        elif duration.split()[0][-1] == 'm':
            x = int(duration.split('m')[0])
        dict_duration[x] = title
        print(x)
# Out:
# 142
# 175
# 152
# 202
# 102
# 122
# 170
# 148
# 181
# 142
# 90
# 146
# 86
# 94
# 83
# 105
# 99
# 172
# 145
# 127
# 130
# 154
# 112
# 164
# 129
# 121
# 93
# 125
# 143
# 98
# 99
# 115
# 101
# 80
# 121
# 123
# 89
# 107
# 137
# 129
# 111
# 120
# 120
# 121
# 152
# 114
# 136
# 117
# 118
# 124
# 128
# 92
# 98
# 96
# 92
# 120
# 129
# 45
# 122
# 132
# 131
# 139
# 93
# 183
# 133
# 185
# 67
# 91
# 149
# 99
# 108
# 212
# 134
# 101
# 130
# 96
# 95
# 117
# 89
# 132
# 86
# 141
# 169
# 116
# 140
# 98
# 153
# 161
# 93
# 115
# 119
# 129
# 95
# 105
# 107
# 238
# 132
# 129
# 130
# 124
# 100
# 148
# 109
# 88
# 172
# 111
# 122
# 91
# 126
# 110
# 127
# 135
# 138
# 107
# 130
# 118
# 158
# 103
# 178
# 162
# 179
# 130
# 180
# 138
# 97
# 121
# 68
# 140
# 132
# 161
# 156
# 130
# 119
# 165
# 89
# 102
# 127
# 132
# 114
# 138
# 153
# 123
# 129
# 96
# 129
# 170
# 131
# 160
# 170
# 116
# 136
# 107
# 122
# 125
# 128
# 136
# 143
# 99
# 218
# 119
# 115
# 99
# 142
# 108
# 149
# 131
# 126
# 103
# 143
# 102
# 170
# 103
# 106
# 126
# 229
# 134
# 181
# 122
# 178
# 81
# 105
# 160
# 153
# 120
# 164
# 95
# 122
# 117
# 137
# 116
# 149
# 125
# 146
# 88
# 110
# 137
# 98
# 115
# 165
# 113
# 147
# 87
# 117
# 112
# 155
# 165
# 87
# 112
# 133
# 89
# 102
# 106
# 130
# 106
# 151
# 119
# 155
# 88
# 110
# 132
# 109
# 150
# 125
# 116
# 137
# 121
# 189
# 116
# 169
# 130
# 169
# 118
# 207
# 130
# 127
# 133
# 145
# 136
# 124
# 148
# 179
# 139
# 142
# 178
# 178
# 154
# 201
# 195
# 96

# %%
# duration = document["duration"]
#     title = document["title"]

def tranform_to_minutes(duration):
    if duration is not None:
        if len(duration.split()) == 2:
            x = int(duration.split()[0][0]) * 60 + int(duration.split()[1][0 : len(duration.split()[1])-1])
        elif duration.split()[0][-1] == 'h':
            x = int(duration.split('h')[0]) * 60
        elif duration.split()[0][-1] == 'm':
            x = int(duration.split('m')[0])
    return x
tranform_to_minutes('2h 22m')
# Out:
# 142
